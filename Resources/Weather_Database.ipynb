# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#import the api key from the config file
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
   
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                         "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | nola
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | aksu
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | santa maria
# Processing Record 8 of Set 1 | nogliki
# Processing Record 9 of Set 1 | labytnangi
# Processing Record 10 of Set 1 | mumford
# Processing Record 11 of Set 1 | oyem
# Processing Record 12 of Set 1 | klyuchi
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | pochutla
# Processing Record 16 of Set 1 | kropotkin
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | nyagan
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | ouesso
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | barcelos
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | alyangula
# Processing Record 35 of Set 1 | baie-comeau
# Processing Record 36 of Set 1 | la palma
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | the valley
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | terrace bay
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | san juan
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | lebedinyy
# Processing Record 1 of Set 2 | basco
# Processing Record 2 of Set 2 | kontagora
# Processing Record 3 of Set 2 | taft
# Processing Record 4 of Set 2 | quelimane
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | tabou
# Processing Record 7 of Set 2 | maniitsoq
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | opotiki
# Processing Record 10 of Set 2 | skjervoy
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | nakatunguru
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | altamira
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | mareeba
# Processing Record 17 of Set 2 | mamou
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | carballo
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | hervey bay
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | portland
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | graham
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 2 | poso
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | nyurba
# Processing Record 34 of Set 2 | zhangye
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | port macquarie
# Processing Record 37 of Set 2 | faya
# Processing Record 38 of Set 2 | verkhnevilyuysk
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | port keats
# Processing Record 43 of Set 2 | arua
# Processing Record 44 of Set 2 | bagdarin
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | gat
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | inta
# Processing Record 1 of Set 3 | mahanoro
# Processing Record 2 of Set 3 | santa luzia
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | grosseto
# Processing Record 5 of Set 3 | kamir
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | tiruchchendur
# Processing Record 9 of Set 3 | idaho falls
# Processing Record 10 of Set 3 | ballina
# Processing Record 11 of Set 3 | playas
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | college place
# Processing Record 14 of Set 3 | saint-joseph
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | sangar
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | ahipara
# Processing Record 20 of Set 3 | berlevag
# Processing Record 21 of Set 3 | hohhot
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | chongwe
# Processing Record 24 of Set 3 | tucuman
# Processing Record 25 of Set 3 | varkkallai
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | fomboni
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | muscle shoals
# Processing Record 32 of Set 3 | nishihara
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | santa lucia
# Processing Record 36 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | praia da vitoria
# Processing Record 38 of Set 3 | san cristobal
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | manadhoo
# Processing Record 41 of Set 3 | tateyama
# Processing Record 42 of Set 3 | nakambala
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | derzhavinsk
# Processing Record 45 of Set 3 | buckeye
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | acarau
# Processing Record 2 of Set 4 | palmer
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | ulaangom
# Processing Record 5 of Set 4 | tay ninh
# Processing Record 6 of Set 4 | victoria
# Processing Record 7 of Set 4 | severnoye
# Processing Record 8 of Set 4 | goure
# Processing Record 9 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 4 | honiara
# Processing Record 11 of Set 4 | parabel
# Processing Record 12 of Set 4 | urumqi
# Processing Record 13 of Set 4 | riberalta
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 4 | semey
# Processing Record 17 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 4 | pahalgam
# Processing Record 19 of Set 4 | mandalgovi
# Processing Record 20 of Set 4 | kurilsk
# Processing Record 21 of Set 4 | vestmanna
# Processing Record 22 of Set 4 | sembe
# Processing Record 23 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 4 | neiafu
# Processing Record 25 of Set 4 | rundu
# Processing Record 26 of Set 4 | oktyabrskoye
# Processing Record 27 of Set 4 | hobart
# Processing Record 28 of Set 4 | kasangulu
# Processing Record 29 of Set 4 | synya
# Processing Record 30 of Set 4 | muscat
# Processing Record 31 of Set 4 | boca do acre
# Processing Record 32 of Set 4 | kashin
# Processing Record 33 of Set 4 | calvia
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | silver city
# Processing Record 36 of Set 4 | jumla
# Processing Record 37 of Set 4 | chkalovskoye
# Processing Record 38 of Set 4 | hasaki
# Processing Record 39 of Set 4 | avera
# Processing Record 40 of Set 4 | sunndalsora
# Processing Record 41 of Set 4 | meadville
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | limot
# Processing Record 44 of Set 4 | svetlogorsk
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | laguna
# Processing Record 48 of Set 4 | lensk
# Processing Record 49 of Set 4 | maldonado
# Processing Record 50 of Set 4 | funtua
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | tilichiki
# Processing Record 3 of Set 5 | kruisfontein
# Processing Record 4 of Set 5 | gondanglegi
# Processing Record 5 of Set 5 | hay river
# Processing Record 6 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 5 | eastbourne
# Processing Record 8 of Set 5 | iberia
# Processing Record 9 of Set 5 | gizo
# Processing Record 10 of Set 5 | urucara
# Processing Record 11 of Set 5 | axim
# Processing Record 12 of Set 5 | lompoc
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | yabelo
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | mandal
# Processing Record 17 of Set 5 | chiang khong
# Processing Record 18 of Set 5 | iskateley
# Processing Record 19 of Set 5 | skegness
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | dickinson
# Processing Record 22 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 5 | tadpatri
# Processing Record 24 of Set 5 | barrow
# Processing Record 25 of Set 5 | roma
# Processing Record 26 of Set 5 | chuy
# Processing Record 27 of Set 5 | moron
# Processing Record 28 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 5 | akyab
# Processing Record 31 of Set 5 | bhag
# Processing Record 32 of Set 5 | koutiala
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 5 | labuhan
# Processing Record 36 of Set 5 | georgetown
# Processing Record 37 of Set 5 | ravenna
# Processing Record 38 of Set 5 | flinders
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | ibipeba
# Processing Record 41 of Set 5 | sept-iles
# Processing Record 42 of Set 5 | rapid valley
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | bud
# Processing Record 45 of Set 5 | zinder
# Processing Record 46 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 5 | viedma
# Processing Record 48 of Set 5 | tambun
# Processing Record 49 of Set 5 | ayan
# Processing Record 50 of Set 5 | makushino
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | suntar
# Processing Record 3 of Set 6 | bohusovice nad ohri
# Processing Record 4 of Set 6 | banda aceh
# Processing Record 5 of Set 6 | marsa matruh
# Processing Record 6 of Set 6 | bunumbu
# Processing Record 7 of Set 6 | ginda
# Processing Record 8 of Set 6 | grande prairie
# Processing Record 9 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 11 of Set 6 | pandan
# Processing Record 12 of Set 6 | makat
# Processing Record 13 of Set 6 | karpogory
# Processing Record 14 of Set 6 | port elizabeth
# Processing Record 15 of Set 6 | cabedelo
# Processing Record 16 of Set 6 | hovd
# Processing Record 17 of Set 6 | asfi
# Processing Record 18 of Set 6 | xining
# Processing Record 19 of Set 6 | bosaso
# Processing Record 20 of Set 6 | alofi
# Processing Record 21 of Set 6 | khiri mat
# Processing Record 22 of Set 6 | malanje
# Processing Record 23 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | iwanai
# Processing Record 26 of Set 6 | kodiak
# Processing Record 27 of Set 6 | neyshabur
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | inirida
# Processing Record 30 of Set 6 | veraval
# Processing Record 31 of Set 6 | vanimo
# Processing Record 32 of Set 6 | ibra
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | padang
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | kutum
# Processing Record 37 of Set 6 | begusarai
# Processing Record 38 of Set 6 | teya
# Processing Record 39 of Set 6 | wasilla
# Processing Record 40 of Set 6 | brae
# Processing Record 41 of Set 6 | roseburg
# Processing Record 42 of Set 6 | aromashevo
# Processing Record 43 of Set 6 | deputatskiy
# Processing Record 44 of Set 6 | dankov
# Processing Record 45 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | santa rosalia
# Processing Record 48 of Set 6 | houston
# Processing Record 49 of Set 6 | bozova
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | myitkyina
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | rocky mountain house
# Processing Record 6 of Set 7 | krasnozatonskiy
# Processing Record 7 of Set 7 | tsabong
# Processing Record 8 of Set 7 | sambalpur
# Processing Record 9 of Set 7 | salalah
# Processing Record 10 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 7 | montrose
# Processing Record 12 of Set 7 | fortuna foothills
# Processing Record 13 of Set 7 | vao
# Processing Record 14 of Set 7 | santa cruz
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | tuatapere
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | pacific grove
# Processing Record 19 of Set 7 | petatlan
# Processing Record 20 of Set 7 | fairbanks
# Processing Record 21 of Set 7 | lagos
# Processing Record 22 of Set 7 | havoysund
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | castro
# Processing Record 25 of Set 7 | izhma
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | zhuhai
# Processing Record 30 of Set 7 | sabang
# Processing Record 31 of Set 7 | coihaique
# Processing Record 32 of Set 7 | yar-sale
# Processing Record 33 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 34 of Set 7 | klaksvik
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | bandarbeyla
# Processing Record 37 of Set 7 | sioux lookout
# Processing Record 38 of Set 7 | yinchuan
# Processing Record 39 of Set 7 | sao felix do xingu
# Processing Record 40 of Set 7 | muros
# Processing Record 41 of Set 7 | parakai
# Processing Record 42 of Set 7 | algiers
# Processing Record 43 of Set 7 | usinsk
# Processing Record 44 of Set 7 | iralaya
# Processing Record 45 of Set 7 | saint-louis
# Processing Record 46 of Set 7 | sandviken
# Processing Record 47 of Set 7 | solnechnyy
# Processing Record 48 of Set 7 | churapcha
# Processing Record 49 of Set 7 | christchurch
# Processing Record 50 of Set 7 | vicuna
# Processing Record 1 of Set 8 | visavadar
# Processing Record 2 of Set 8 | pangnirtung
# Processing Record 3 of Set 8 | vysokogornyy
# Processing Record 4 of Set 8 | nuuk
# Processing Record 5 of Set 8 | tecoanapa
# Processing Record 6 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 8 | bathsheba
# Processing Record 8 of Set 8 | meulaboh
# Processing Record 9 of Set 8 | lexington park
# Processing Record 10 of Set 8 | umarkot
# Processing Record 11 of Set 8 | airai
# Processing Record 12 of Set 8 | nemuro
# Processing Record 13 of Set 8 | torrington
# Processing Record 14 of Set 8 | ugoofaaru
# Processing Record 15 of Set 8 | torbay
# Processing Record 16 of Set 8 | arlit
# Processing Record 17 of Set 8 | sabibah
# City not found. Skipping...
# Processing Record 18 of Set 8 | warrnambool
# Processing Record 19 of Set 8 | sabha
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | miyako
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | broken hill
# Processing Record 24 of Set 8 | ipixuna
# Processing Record 25 of Set 8 | sumbuya
# Processing Record 26 of Set 8 | mitu
# Processing Record 27 of Set 8 | moussoro
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | hobyo
# Processing Record 30 of Set 8 | hami
# Processing Record 31 of Set 8 | zalantun
# Processing Record 32 of Set 8 | pirovskoye
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | cuamba
# Processing Record 35 of Set 8 | umm kaddadah
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | venice
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | namibe
# Processing Record 40 of Set 8 | vostok
# Processing Record 41 of Set 8 | surman
# Processing Record 42 of Set 8 | salisbury
# Processing Record 43 of Set 8 | anadyr
# Processing Record 44 of Set 8 | lubango
# Processing Record 45 of Set 8 | hinton
# Processing Record 46 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | port blair
# Processing Record 50 of Set 8 | lake havasu city
# Processing Record 1 of Set 9 | wajir
# Processing Record 2 of Set 9 | port moresby
# Processing Record 3 of Set 9 | lokosovo
# Processing Record 4 of Set 9 | kudahuvadhoo
# Processing Record 5 of Set 9 | izumo
# Processing Record 6 of Set 9 | borzna
# Processing Record 7 of Set 9 | lewistown
# Processing Record 8 of Set 9 | chau doc
# Processing Record 9 of Set 9 | north bend
# Processing Record 10 of Set 9 | rawatsar
# Processing Record 11 of Set 9 | ankang
# Processing Record 12 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 9 | husum
# Processing Record 14 of Set 9 | alta floresta
# Processing Record 15 of Set 9 | tigil
# Processing Record 16 of Set 9 | herat
# Processing Record 17 of Set 9 | arman
# Processing Record 18 of Set 9 | korla
# Processing Record 19 of Set 9 | abakaliki
# Processing Record 20 of Set 9 | dongsheng
# Processing Record 21 of Set 9 | bosanski novi
# Processing Record 22 of Set 9 | zhigansk
# Processing Record 23 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 9 | opuwo
# Processing Record 25 of Set 9 | conceicao do coite
# Processing Record 26 of Set 9 | baturaja
# Processing Record 27 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 9 | mayor pablo lagerenza
# Processing Record 29 of Set 9 | zhicheng
# Processing Record 30 of Set 9 | takoradi
# Processing Record 31 of Set 9 | qaqortoq
# Processing Record 32 of Set 9 | russell
# Processing Record 33 of Set 9 | am timan
# Processing Record 34 of Set 9 | saint-georges
# Processing Record 35 of Set 9 | boyolangu
# Processing Record 36 of Set 9 | sao geraldo do araguaia
# Processing Record 37 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 38 of Set 9 | alghero
# Processing Record 39 of Set 9 | ovre ardal
# Processing Record 40 of Set 9 | lahij
# Processing Record 41 of Set 9 | pasinler
# Processing Record 42 of Set 9 | quatre cocos
# Processing Record 43 of Set 9 | chimoio
# Processing Record 44 of Set 9 | narnaul
# Processing Record 45 of Set 9 | puri
# Processing Record 46 of Set 9 | skeldon
# Processing Record 47 of Set 9 | mapiripan
# Processing Record 48 of Set 9 | samarai
# Processing Record 49 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 50 of Set 9 | manta
# Processing Record 1 of Set 10 | batagay
# Processing Record 2 of Set 10 | kamenka
# Processing Record 3 of Set 10 | daru
# Processing Record 4 of Set 10 | ambilobe
# Processing Record 5 of Set 10 | fukue
# Processing Record 6 of Set 10 | port hedland
# Processing Record 7 of Set 10 | mayo
# Processing Record 8 of Set 10 | havelock
# Processing Record 9 of Set 10 | saint-pierre
# Processing Record 10 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 10 | queanbeyan
# Processing Record 12 of Set 10 | shenjiamen
# Processing Record 13 of Set 10 | sorong
# Processing Record 14 of Set 10 | wattegama
# Processing Record 15 of Set 10 | royan
# Processing Record 16 of Set 10 | bonthe
# Processing Record 17 of Set 10 | karanja
# Processing Record 18 of Set 10 | puro
# Processing Record 19 of Set 10 | traiguen
# Processing Record 20 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 10 | kumluca
# Processing Record 22 of Set 10 | asau
# Processing Record 23 of Set 10 | la ronge
# Processing Record 24 of Set 10 | kiama
# Processing Record 25 of Set 10 | vila velha
# Processing Record 26 of Set 10 | arawa
# Processing Record 27 of Set 10 | chipinge
# Processing Record 28 of Set 10 | rocha
# Processing Record 29 of Set 10 | alakurtti
# Processing Record 30 of Set 10 | moose factory
# Processing Record 31 of Set 10 | ketchikan
# Processing Record 32 of Set 10 | peleduy
# Processing Record 33 of Set 10 | saint george
# Processing Record 34 of Set 10 | springdale
# Processing Record 35 of Set 10 | perth
# Processing Record 36 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 10 | angoche
# Processing Record 38 of Set 10 | atar
# Processing Record 39 of Set 10 | coahuayana
# Processing Record 40 of Set 10 | kosa
# Processing Record 41 of Set 10 | matara
# Processing Record 42 of Set 10 | chowchilla
# Processing Record 43 of Set 10 | da nang
# Processing Record 44 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 10 | sale
# Processing Record 46 of Set 10 | coquimbo
# Processing Record 47 of Set 10 | tairua
# Processing Record 48 of Set 10 | casma
# Processing Record 49 of Set 10 | alugan
# Processing Record 50 of Set 10 | payakumbuh
# Processing Record 1 of Set 11 | sakhipur
# Processing Record 2 of Set 11 | camacupa
# Processing Record 3 of Set 11 | kiomboi
# Processing Record 4 of Set 11 | suhbaatar
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | mehamn
# Processing Record 7 of Set 11 | bridlington
# Processing Record 8 of Set 11 | santa fe
# Processing Record 9 of Set 11 | goderich
# Processing Record 10 of Set 11 | ulladulla
# Processing Record 11 of Set 11 | lenine
# Processing Record 12 of Set 11 | villa oliva
# City not found. Skipping...
# Processing Record 13 of Set 11 | bonfim
# Processing Record 14 of Set 11 | kirksville
# Processing Record 15 of Set 11 | saint anthony
# Processing Record 16 of Set 11 | hanchuan
# Processing Record 17 of Set 11 | hluti
# Processing Record 18 of Set 11 | kumba
# Processing Record 19 of Set 11 | tuy hoa
# Processing Record 20 of Set 11 | jiblah
# Processing Record 21 of Set 11 | marigot
# Processing Record 22 of Set 11 | ulaanbaatar
# Processing Record 23 of Set 11 | genhe
# Processing Record 24 of Set 11 | sinnamary
# Processing Record 25 of Set 11 | tocopilla
# Processing Record 26 of Set 11 | andenes
# Processing Record 27 of Set 11 | general roca
# Processing Record 28 of Set 11 | burnie
# Processing Record 29 of Set 11 | sibolga
# Processing Record 30 of Set 11 | lata
# Processing Record 31 of Set 11 | bercel
# Processing Record 32 of Set 11 | chusovoy
# Processing Record 33 of Set 11 | morehead
# Processing Record 34 of Set 11 | umm lajj
# Processing Record 35 of Set 11 | presidencia roque saenz pena
# Processing Record 36 of Set 11 | tankhoy
# Processing Record 37 of Set 11 | thaba-tseka
# Processing Record 38 of Set 11 | caraquet
# Processing Record 39 of Set 11 | kloulklubed
# Processing Record 40 of Set 11 | bereda
# Processing Record 41 of Set 11 | perdoes
# Processing Record 42 of Set 11 | muroto
# Processing Record 43 of Set 11 | merritt island
# Processing Record 44 of Set 11 | taltal
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | arinos
# Processing Record 47 of Set 11 | olinda
# Processing Record 48 of Set 11 | warrington
# Processing Record 49 of Set 11 | yulara
# Processing Record 50 of Set 11 | sukhothai
# Processing Record 1 of Set 12 | cayenne
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 12 | abeche
# Processing Record 5 of Set 12 | mardin
# Processing Record 6 of Set 12 | okhotsk
# Processing Record 7 of Set 12 | caravelas
# Processing Record 8 of Set 12 | dingle
# Processing Record 9 of Set 12 | half moon bay
# Processing Record 10 of Set 12 | aldan
# Processing Record 11 of Set 12 | hibbing
# Processing Record 12 of Set 12 | auki
# Processing Record 13 of Set 12 | lumut
# Processing Record 14 of Set 12 | basay
# Processing Record 15 of Set 12 | asuncion
# Processing Record 16 of Set 12 | tiznit
# Processing Record 17 of Set 12 | ratangarh
# Processing Record 18 of Set 12 | rockland
# Processing Record 19 of Set 12 | dudinka
# Processing Record 20 of Set 12 | tautira
# Processing Record 21 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 12 | sandpoint
# Processing Record 23 of Set 12 | mogadishu
# Processing Record 24 of Set 12 | kenai
# Processing Record 25 of Set 12 | ruangwa
# Processing Record 26 of Set 12 | tessalit
# Processing Record 27 of Set 12 | maceio
# Processing Record 28 of Set 12 | camacha
# Processing Record 29 of Set 12 | andalan
# Processing Record 30 of Set 12 | itamaraca
# Processing Record 31 of Set 12 | nampula
# Processing Record 32 of Set 12 | golden
# Processing Record 33 of Set 12 | lake cowichan
# Processing Record 34 of Set 12 | hasanabad
# Processing Record 35 of Set 12 | high level
# Processing Record 36 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | alice springs
# Processing Record 39 of Set 12 | huallanca
# Processing Record 40 of Set 12 | filingue
# Processing Record 41 of Set 12 | sharjah
# Processing Record 42 of Set 12 | channel-port aux basques
# Processing Record 43 of Set 12 | tambura
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | ashtian
# Processing Record 46 of Set 12 | salinopolis
# Processing Record 47 of Set 12 | sangueya
# Processing Record 48 of Set 12 | uvat
# Processing Record 49 of Set 12 | namatanai
# Processing Record 50 of Set 12 | ilebo
# Processing Record 1 of Set 13 | hualmay
# Processing Record 2 of Set 13 | sao joao da barra
# Processing Record 3 of Set 13 | maua
# Processing Record 4 of Set 13 | lake charles
# Processing Record 5 of Set 13 | shitanjing
# Processing Record 6 of Set 13 | jinchang
# Processing Record 7 of Set 13 | voh
# Processing Record 8 of Set 13 | kichera
# Processing Record 9 of Set 13 | acapulco
# Processing Record 10 of Set 13 | vila
# Processing Record 11 of Set 13 | mahebourg
# Processing Record 12 of Set 13 | mitsamiouli
# Processing Record 13 of Set 13 | taylor
# Processing Record 14 of Set 13 | mao
# Processing Record 15 of Set 13 | catalina
# Processing Record 16 of Set 13 | rakhya
# City not found. Skipping...
# Processing Record 17 of Set 13 | quarai
# Processing Record 18 of Set 13 | yunyang
# Processing Record 19 of Set 13 | ahome
# Processing Record 20 of Set 13 | shelbyville
# Processing Record 21 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 13 | jalu
# Processing Record 23 of Set 13 | eydhafushi
# Processing Record 24 of Set 13 | shahr-e kord
# Processing Record 25 of Set 13 | neuquen
# Processing Record 26 of Set 13 | tukrah
# Processing Record 27 of Set 13 | sambava
# Processing Record 28 of Set 13 | abu samrah
# Processing Record 29 of Set 13 | leshukonskoye
# Processing Record 30 of Set 13 | san policarpo
# Processing Record 31 of Set 13 | caborca
# Processing Record 32 of Set 13 | balabac
# Processing Record 33 of Set 13 | walvis bay
# Processing Record 34 of Set 13 | monzon
# Processing Record 35 of Set 13 | lander
# Processing Record 36 of Set 13 | ust-koksa
# Processing Record 37 of Set 13 | jijiga
# Processing Record 38 of Set 13 | lexington
# Processing Record 39 of Set 13 | geraldton
# Processing Record 40 of Set 13 | southbridge
# Processing Record 41 of Set 13 | krasnoselkup
# Processing Record 42 of Set 13 | nalut
# Processing Record 43 of Set 13 | los llanos de aridane
# Processing Record 44 of Set 13 | vardo
# Processing Record 45 of Set 13 | ryotsu
# Processing Record 46 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 13 | tevaitoa
# Processing Record 48 of Set 13 | caraballeda
# Processing Record 49 of Set 13 | troitskoye
# Processing Record 50 of Set 13 | palana
# Processing Record 1 of Set 14 | port lincoln
# Processing Record 2 of Set 14 | kulhudhuffushi
# Processing Record 3 of Set 14 | coihueco
# Processing Record 4 of Set 14 | casper
# Processing Record 5 of Set 14 | waipawa
# Processing Record 6 of Set 14 | san pedro
# Processing Record 7 of Set 14 | slave lake
# Processing Record 8 of Set 14 | verkhnyaya inta
# Processing Record 9 of Set 14 | eureka
# Processing Record 10 of Set 14 | punta umbria
# Processing Record 11 of Set 14 | starobaltachevo
# Processing Record 12 of Set 14 | roald
# Processing Record 13 of Set 14 | hudson bay
# Processing Record 14 of Set 14 | morozovsk
# Processing Record 15 of Set 14 | talcahuano
# Processing Record 16 of Set 14 | tacoronte
# Processing Record 17 of Set 14 | whitehorse
# Processing Record 18 of Set 14 | adelaide
# Processing Record 19 of Set 14 | beder
# Processing Record 20 of Set 14 | sarahan
# Processing Record 21 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 14 | gambela
# Processing Record 23 of Set 14 | lockerbie
# Processing Record 24 of Set 14 | phek
# Processing Record 25 of Set 14 | jinka
# Processing Record 26 of Set 14 | weston
# Processing Record 27 of Set 14 | ixtapa
# Processing Record 28 of Set 14 | tanout
# Processing Record 29 of Set 14 | margate
# Processing Record 30 of Set 14 | leningradskiy
# Processing Record 31 of Set 14 | kajaani
# Processing Record 32 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 33 of Set 14 | ponferrada
# Processing Record 34 of Set 14 | carutapera
# Processing Record 35 of Set 14 | naze
# Processing Record 36 of Set 14 | soller
# Processing Record 37 of Set 14 | teeli
# Processing Record 38 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 14 | beitbridge
# Processing Record 40 of Set 14 | syracuse
# Processing Record 41 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 14 | sao benedito do rio preto
# Processing Record 43 of Set 14 | hanzhong
# Processing Record 44 of Set 14 | kadaya
# Processing Record 45 of Set 14 | amuntai
# Processing Record 46 of Set 14 | cozumel
# Processing Record 47 of Set 14 | aloleng
# Processing Record 48 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 49 of Set 14 | kijang
# Processing Record 50 of Set 14 | shumskiy
# Processing Record 1 of Set 15 | baykit
# Processing Record 2 of Set 15 | kushima
# Processing Record 3 of Set 15 | karratha
# Processing Record 4 of Set 15 | esmeraldas
# Processing Record 5 of Set 15 | kirakira
# Processing Record 6 of Set 15 | lecce
# Processing Record 7 of Set 15 | dzhebariki-khaya
# Processing Record 8 of Set 15 | mocuba
# Processing Record 9 of Set 15 | beihai
# Processing Record 10 of Set 15 | coxim
# Processing Record 11 of Set 15 | teguldet
# Processing Record 12 of Set 15 | kadhan
# Processing Record 13 of Set 15 | independence
# Processing Record 14 of Set 15 | okitipupa
# Processing Record 15 of Set 15 | paamiut
# Processing Record 16 of Set 15 | tonaya
# Processing Record 17 of Set 15 | belaya gora
# Processing Record 18 of Set 15 | tazmalt
# Processing Record 19 of Set 15 | qui nhon
# Processing Record 20 of Set 15 | shetpe
# Processing Record 21 of Set 15 | ningxiang
# Processing Record 22 of Set 15 | richards bay
# Processing Record 23 of Set 15 | dukat
# Processing Record 24 of Set 15 | paita
# Processing Record 25 of Set 15 | bilma
# Processing Record 26 of Set 15 | tahoua
# Processing Record 27 of Set 15 | darhan
# Processing Record 28 of Set 15 | kamyaran
# Processing Record 29 of Set 15 | canandaigua
# Processing Record 30 of Set 15 | dahanu
# Processing Record 31 of Set 15 | itaituba
# Processing Record 32 of Set 15 | grivenskaya
# Processing Record 33 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 15 | balikpapan
# Processing Record 35 of Set 15 | bontang
# Processing Record 36 of Set 15 | kalmunai
# Processing Record 37 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 15 | ola
# Processing Record 39 of Set 15 | floresta
# Processing Record 40 of Set 15 | chake chake
# Processing Record 41 of Set 15 | piranshahr
# Processing Record 42 of Set 15 | plouzane
# Processing Record 43 of Set 15 | adrar
# Processing Record 44 of Set 15 | ust-nera
# Processing Record 45 of Set 15 | miaray
# Processing Record 46 of Set 15 | mahajanga
# Processing Record 47 of Set 15 | atambua
# Processing Record 48 of Set 15 | vorobyevka
# Processing Record 49 of Set 15 | obo
# Processing Record 50 of Set 15 | kologriv
# Processing Record 1 of Set 16 | nacozari
# Processing Record 2 of Set 16 | udachnyy
# Processing Record 3 of Set 16 | sarakhs
# Processing Record 4 of Set 16 | katherine
# Processing Record 5 of Set 16 | bonavista
# Processing Record 6 of Set 16 | kampene
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Nola  40.9220   14.5329     84.92        27          48        1.57
# 1     Hermanus -34.4187   19.2345     52.90        65           2       11.01
# 2      Rikitea -23.1203 -134.9692     74.98        81          98       18.41
# 3  Port Alfred -33.5906   26.8910     61.45        31          30       11.21
# 4         Aksu  41.1231   80.2644     93.18        16           1        7.63
# 5      Mataura -46.1927  168.8643     52.48        70          13        4.74
# 6  Santa Maria -29.6842  -53.8069     56.23        96         100        8.39
# 7      Nogliki  51.8333  143.1667     70.99        84         100        8.66
# 8   Labytnangi  66.6572   66.4183     53.29        76          77       10.42
# 9      Mumford   5.2618   -0.7590     75.58        77          98       11.99
#
#   Country Current Description
# 0      IT    scattered clouds
# 1      ZA           clear sky
# 2      PF          light rain
# 3      ZA    scattered clouds
# 4      CN           clear sky
# 5      NZ          few clouds
# 6      BR     overcast clouds
# 7      RU     overcast clouds
# 8      RU       broken clouds
# 9      GH     overcast clouds

# %%
#reorder columns

new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
